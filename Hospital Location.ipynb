# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import gmaps

# Import API key
from connors_config import gkey

# Configure gmaps
gmaps.configure(api_key=gkey)

# %%
hospitals = "Hospitals_new.csv"
Final_SE = "Final_SE_df.csv"
number_of_hospitals = "Number_of_Hospitals_Per_Zip.csv"

# %%
hospitals_df = pd.read_csv(hospitals, converters={'Zip': lambda x: str(x)})
Final_SE_df = pd.read_csv(Final_SE, converters={'Zipcode': lambda x: str(x)})
number_of_hospitals_df = pd.read_csv(Final_SE, converters={'Zipcode': lambda x: str(x)})

# %%
full_zips = [zip for zip in hospitals_df["ZIP"]]
correct_zips = []

for zip in full_zips:
   while len(str(zip)) < 5:
       zip = "0" + str(zip)
   correct_zips.append(zip)
   
hospitals_df["ZIP_New"] = correct_zips

# %%
number_of_hospitals_df.head()
# Out:
#   Zipcode State      Urban Type  Center Point Lat  Center Point Lng  \
# 0   00601    PR           Mixed         18.180555        -66.749961
# 1   00602    PR  Urbanized Area         18.361945        -67.175597
# 2   00603    PR  Urbanized Area         18.455183        -67.119887
# 3   00606    PR           Mixed         18.158345        -66.932911
# 4   00610    PR  Urbanized Area         18.295366        -67.125135
#
#    Population  Pop Density  Median Age ZC Eth  Pct Dom Eth    ...      \
# 0     17982.0   279.449245        37.6    His    99.777555    ...
# 1     40260.0  1315.127560        39.5    His    93.594138    ...
# 2     52408.0  1657.641700        39.9    His    96.239124    ...
# 3      6331.0   149.637193        40.8    His    99.873638    ...
# 4     28328.0   788.729257        40.2    His    98.838605    ...
#
#      Lng_Pct House_Const_Yr  Med Gross Rent  Med Home_Val  Household Income  \
# ...

# %%
#create thing to loop through geopy.distance for each hospial after comparing hospital zip and brian's zip
#MAKE SURE TO CREATE EXCEPTION HANDLING IF THERE ARE NAN VALUES
#create df that contains the hospitals, their location, and have a space ready to append in distance to the center of the
#nearest zipcode and said zipcode
count == 0

for 
    from geopy.distance import lonlat, distance
    hospital_loc = ("hospitals.csv lon", "hospitals.csv lat")
    zipcode_center = ("Brian's lon", "Brian's lat")
    print(distance(lonlat(*hospital_loc), lonlat(*zipcode_center)).miles)
    #append the value into a df
    count = count + 1
# Out:
#   File "<ipython-input-6-438ae76d379b>", line 7
#     for
#         ^
# SyntaxError: invalid syntax

# %%
# Store latitude and longitude in locations
locations = number_of_hospitals_df[["Center Point Lat", "Center Point Lng"]]

# Fill NaN values and convert to float
hospital_density = number_of_hospitals_df["ID"].astype(float)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# D:\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2524             try:
# -> 2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'ID'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-231784fbf0c0> in <module>()
#       3
# ...

# %%
# Plot Heatmap
fig = gmaps.figure()

# Create heat layer
heat_layer = gmaps.heatmap_layer(locations, weights=hospital_density, 
                                 dissipating=False, max_intensity=10,
                                 point_radius=1)


# Add layer
fig.add_layer(heat_layer)

# Display figure
fig
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-a561237e13cc> in <module>()
#       3
#       4 # Create heat layer
# ----> 5 heat_layer = gmaps.heatmap_layer(locations, weights=hospital_density,
#       6                                  dissipating=False, max_intensity=10,
#       7                                  point_radius=1)
#
# NameError: name 'locations' is not defined
